# %%
import pandas as pd

# ini load dataset
df= pd.read_csv("food_coded.csv")

# ini baca 5 paling atas, buat mastiin datanya jalan
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
# cek info dataset
df.info()

# saya cek ada beberapa yang kosong
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
# Disini saya makesure lagi secara keseluruhan total missing values
missing_cols = df.columns[df.isnull().any()]
print(df[missing_cols].isnull().sum())
# Out:
# GPA                            2
# calories_day                  19
# calories_scone                 1
# comfort_food                   1
# comfort_food_reasons           1
# comfort_food_reasons_coded    19
# cook                           3
# cuisine                       17
# diet_current                   1
# drink                          2
# eating_changes                 3
# employment                     9
# exercise                      13
# father_education               1
# father_profession              3
# fav_cuisine                    2
# fav_food                       2
# food_childhood                 1
# healthy_meal                   1
# ideal_diet                     1
# income                         1
# life_rewarding                 1
# marital_status                 1
# meals_dinner_friend            3
# mother_education               3
# mother_profession              2
# on_off_campus                  1
# persian_food                   1
# ...

# %%
# disini saya cek missing value dalam bentuk persen
missing_percent = (df[missing_cols].isnull().sum() / len(df)) * 100
print(missing_percent)
# Out:
# GPA                            1.6
# calories_day                  15.2
# calories_scone                 0.8
# comfort_food                   0.8
# comfort_food_reasons           0.8
# comfort_food_reasons_coded    15.2
# cook                           2.4
# cuisine                       13.6
# diet_current                   0.8
# drink                          1.6
# eating_changes                 2.4
# employment                     7.2
# exercise                      10.4
# father_education               0.8
# father_profession              2.4
# fav_cuisine                    1.6
# fav_food                       1.6
# food_childhood                 0.8
# healthy_meal                   0.8
# ideal_diet                     0.8
# income                         0.8
# life_rewarding                 0.8
# marital_status                 0.8
# meals_dinner_friend            2.4
# mother_education               2.4
# mother_profession              1.6
# on_off_campus                  0.8
# ...

# %%
# Imputasi data numerik dengan mean
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# Imputasi data kategorikal dengan modus
cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# memastikan sudah selsai masalahnya
print(df.isnull().sum().sum())
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           125 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    float64
#  5   calories_scone                125 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  125 non-null    object
#  8   comfort_food_reasons          125 non-null    object
#  9   comfort_food_reasons_coded    125 non-null    float64
#  10  cook                          125 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
# Ubah kolom numerik yang masih object ke float, yaitu GPA
df['GPA'] = pd.to_numeric(df['GPA'], errors='coerce')
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')

# MENGECEK hasilnya kembali
df[['GPA', 'weight']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GPA     122 non-null    float64
#  1   weight  122 non-null    float64
# dtypes: float64(2)
# memory usage: 2.1 KB

# %%
# export ke csv dimana datanya udh clean
df.to_csv('food_coded_clean.csv', index=False)
